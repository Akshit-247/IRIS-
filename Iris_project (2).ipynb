# %%
import pandas as pd

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_excel('iris-train.xlsx')

# %%
x = data.iloc[: , : -1] # features

# %%
y = data.iloc[: , -1] # labes

# %%
model = RandomForestClassifier()
model = model.fit(x.values , y.values)

# %%
model
# Out:
# RandomForestClassifier()

# %%
predict = model.predict([[2, 0.2, 5, 2.2]])

# %%
print(predict)
# Out:
# ['Iris-virginica']

# %%
newdata = pd.read_excel('iris-test.xlsx')

# %%
newx = newdata.iloc[: , : -1] # feature

# %%
newy = newdata.iloc[: , -1] # labes

# %%
pree = model.predict(newx.values)

# %%
accury = newy.values # is ka values hai voh feature se match hora hai ki nai check kr na

# %%
count = 0
for i in range(0 , len(accury)):
    if accury[i] == pree[i]:
        count = count + 1

print((count * 100) / len(accury))
# Out:
# 97.05882352941177
